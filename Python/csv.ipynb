# %%
import pandas as pd
x = pd.read_csv("5prog_1experience.csv")

# %%
x
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2
# 5              2.9
# 6              3.0
# 7              3.2
# 8              3.2

# %%
x.shape
# Out:
# (9, 1)

# %%
len(x)
# Out:
# 9

# %%
x.head()
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2

# %%
x.tail(2)
# Out:
#    YearsExperience
# 7              3.2
# 8              3.2
